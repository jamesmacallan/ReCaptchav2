# %% [markdown]
# # EDA: No Modifications to Dataset

# %%
import os
dir_path = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images/Bicycle"
Bicycle = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images/Bridge"
Bridge = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images/Bus"
Bus = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images/Car"
Car = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images/Chimney"
Chimney = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images/Crosswalk"
Crosswalk = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images/Hydrant"
Hydrant = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images/Motorcycle"
Motorcycle = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images/Other"
Other = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images/Palm"
Palm = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images/Stair"
Stair = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images/Traffic Light"
Traffic_light = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

# %%
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(12, 8), dpi=80)

data = {'Bicycle': Bicycle,
        'Bridge': Bridge, 
        'Bus': Bus, 
        'Car': Car, 
        'Chimney': Chimney, 
        'Crosswalk': Crosswalk, 
        'Hydrant': Hydrant, 
        'Motorcycle': Motorcycle, 
        'Other': Other, 
        'Palm': Palm, 
        'Stair': Stair, 
        'Traffic light': Traffic_light}
names = list(data.keys())
values = list(data.values())

plt.bar(range(len(data)), values, tick_label=names)
plt.show()

# %% [markdown]
# # Upsampling With Logic

# %%
dir_path = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images/Bicycle"
Bicycle = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images/Bridge"
Bridge = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images/Bus"
Bus = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images/Car"
Car = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images/Chimney"
Chimney = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images/Crosswalk"
Crosswalk = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images/Hydrant"
Hydrant = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images/Motorcycle"
Motorcycle = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images/Other"
Other = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images/Palm"
Palm = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images/Stair"
Stair = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

dir_path = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images/Traffic Light"
Traffic_light = len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

# %%
figure(figsize=(12, 8), dpi=80)

data = {'Bicycle': Bicycle,
        'Bridge': Bridge, 
        'Bus': Bus, 
        'Car': Car, 
        'Chimney': Chimney, 
        'Crosswalk': Crosswalk, 
        'Hydrant': Hydrant, 
        'Motorcycle': Motorcycle, 
        'Other': Other, 
        'Palm': Palm, 
        'Stair': Stair, 
        'Traffic light': Traffic_light}
names = list(data.keys())
values = list(data.values())

plt.bar(range(len(data)), values, tick_label=names)
plt.show()

# %% [markdown]
# # Loading Images and Preprocessing them

# %%
# You can modify the directory in train_ds & val_ds

# %%
# original directory
image_directory = r"C:\Users\jmand\Downloads\recaptchaimages\Google_Recaptcha_V2_Images_Dataset\images"

# %%
# disregard, this version of upsampling was a bad idea. 
image_directory2 = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset\images"

# %%
# upsampled data, currently what the model under the "Our Best Model" section is trained on. 
image_directory3 = r"C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images"

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
img_height = 256
img_width = 256
batch_size = 32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  image_directory3,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 11775 files belonging to 12 classes.
# Using 9420 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  image_directory3,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 11775 files belonging to 12 classes.
# Using 2355 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Bicycle', 'Bridge', 'Bus', 'Car', 'Chimney', 'Crosswalk', 'Hydrant', 'Motorcycle', 'Other', 'Palm', 'Stair', 'Traffic Light']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
num_classes = len(class_names)

# %% [markdown]
# # Creating CNN

# %%
# from keras.models import Sequential
# from keras.layers import Conv2D, MaxPooling2D
# from keras.layers import Activation, Dropout, Flatten, Dense
# from keras import backend as K
# from keras import regularizers
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling (Rescaling)       (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 128)               8388736
#
#  dense_1 (Dense)             (None, 12)                1548
#
# ...
# Total params: 8,413,868
# Trainable params: 8,413,868
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 294/294 [==============================] - 329s 1s/step - loss: 1.9213 - accuracy: 0.3602 - val_loss: 1.6712 - val_accuracy: 0.4335
# Epoch 2/10
# 294/294 [==============================] - 292s 991ms/step - loss: 1.4933 - accuracy: 0.4867 - val_loss: 1.5174 - val_accuracy: 0.4893
# Epoch 3/10
# 294/294 [==============================] - 291s 990ms/step - loss: 1.1556 - accuracy: 0.6020 - val_loss: 1.3880 - val_accuracy: 0.5243
# Epoch 4/10
# 294/294 [==============================] - 290s 986ms/step - loss: 0.7958 - accuracy: 0.7315 - val_loss: 1.5820 - val_accuracy: 0.5179
# Epoch 5/10
# 294/294 [==============================] - 289s 982ms/step - loss: 0.4549 - accuracy: 0.8476 - val_loss: 1.9459 - val_accuracy: 0.5081
# Epoch 6/10
# 294/294 [==============================] - 288s 981ms/step - loss: 0.2078 - accuracy: 0.9385 - val_loss: 2.4990 - val_accuracy: 0.5179
# Epoch 7/10
# ...

# %% [markdown]
# # Visualizing Learning Curves

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Augmenting Data to increase Training Size

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.2), # specify maximum % of rotation
    layers.RandomZoom(0.5), # specify maximum % of zoom
  ]
)
# Random Rotation has a maximum of 20% and RandomZoom has a maximum of 50%
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# ...

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# ...

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# ...

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential_1 (Sequential)   (None, 256, 256, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 128, 128, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 65536)             0
#
#  dense_2 (Dense)             (None, 128)               8388736
#
#  dense_3 (Dense)             (None, 12)                1548
#
# ...
# Total params: 8,413,868
# Trainable params: 8,413,868
# Non-trainable params: 0
# ...

# %%
epochs = 10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation2 = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1), # specify maximum % of rotation
    layers.RandomZoom(0.1), # specify maximum % of zoom
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation2(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# ...

# %%
model = Sequential([
  data_augmentation2,
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
#       1 model = Sequential([
# ----> 2   data_augmentation2,
#       3   layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
#       4   layers.Conv2D(16, 3, padding='same', activation='relu'),
#       5   layers.MaxPooling2D(),
#       6   layers.Conv2D(32, 3, padding='same', activation='relu'),
#       7   layers.MaxPooling2D(),
#       8   layers.Conv2D(64, 3, padding='same', activation='relu'),
#       9   layers.MaxPooling2D(),
#      10   layers.Flatten(),
#      11   layers.Dense(128, activation='relu'),
#      12   layers.Dense(num_classes)
#      13 ])
#
# NameError: name 'data_augmentation2' is not defined

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation3 = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.2), # specify maximum % of rotation
    layers.RandomZoom(0.2), # specify maximum % of zoom
  ]
)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# ...

# %%
model = Sequential([
  data_augmentation3,
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# ...

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# ...

# %% [markdown]
# # Applying Drop Out to decrease Overfitting

# %%
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_4 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_12 (Conv2D)          (None, 256, 256, 16)      448
#
#  max_pooling2d_12 (MaxPoolin  (None, 128, 128, 16)     0
#  g2D)
#
#  dropout (Dropout)           (None, 128, 128, 16)      0
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 32)      4640
#
#  max_pooling2d_13 (MaxPoolin  (None, 64, 64, 32)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 64)        18496
#
#  max_pooling2d_14 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 64)        0
#
#  flatten_4 (Flatten)         (None, 65536)             0
#
#  dense_8 (Dense)             (None, 128)               8388736
#
#  outputs (Dense)             (None, 12)                1548
#
# ...

# %%
epochs = 10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 294/294 [==============================] - 334s 1s/step - loss: 1.9600 - accuracy: 0.3503 - val_loss: 1.8891 - val_accuracy: 0.3870
# Epoch 2/10
# 294/294 [==============================] - 332s 1s/step - loss: 1.6828 - accuracy: 0.4204 - val_loss: 1.6420 - val_accuracy: 0.4352
# Epoch 3/10
# 294/294 [==============================] - 333s 1s/step - loss: 1.5020 - accuracy: 0.4747 - val_loss: 1.5513 - val_accuracy: 0.4668
# Epoch 4/10
# 294/294 [==============================] - 331s 1s/step - loss: 1.2942 - accuracy: 0.5464 - val_loss: 1.5119 - val_accuracy: 0.5090
# Epoch 5/10
# 294/294 [==============================] - 331s 1s/step - loss: 1.0872 - accuracy: 0.6217 - val_loss: 1.5103 - val_accuracy: 0.5043
# Epoch 6/10
# 294/294 [==============================] - 331s 1s/step - loss: 0.8537 - accuracy: 0.7014 - val_loss: 1.5195 - val_accuracy: 0.5269
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Applying Batch Normalization to decrease overfitting

# %%
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_5 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_15 (Conv2D)          (None, 256, 256, 16)      448
#
#  batch_normalization (BatchN  (None, 256, 256, 16)     64
#  ormalization)
#
#  max_pooling2d_15 (MaxPoolin  (None, 128, 128, 16)     0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 32)      4640
#
#  batch_normalization_1 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  max_pooling2d_16 (MaxPoolin  (None, 64, 64, 32)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  max_pooling2d_17 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 65536)             0
#
#  dense_9 (Dense)             (None, 128)               8388736
#
# ...

# %%
epochs = 10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 294/294 [==============================] - 413s 1s/step - loss: 2.4517 - accuracy: 0.3397 - val_loss: 31.2691 - val_accuracy: 0.0904
# Epoch 2/10
# 294/294 [==============================] - 407s 1s/step - loss: 1.9280 - accuracy: 0.3725 - val_loss: 1.9312 - val_accuracy: 0.3730
# Epoch 3/10
# 294/294 [==============================] - 407s 1s/step - loss: 1.7658 - accuracy: 0.3930 - val_loss: 1.8863 - val_accuracy: 0.3828
# Epoch 4/10
# 294/294 [==============================] - 405s 1s/step - loss: 1.6566 - accuracy: 0.4109 - val_loss: 1.8036 - val_accuracy: 0.4062
# Epoch 5/10
# 294/294 [==============================] - 407s 1s/step - loss: 1.5902 - accuracy: 0.4270 - val_loss: 2.7774 - val_accuracy: 0.2140
# Epoch 6/10
# 294/294 [==============================] - 406s 1s/step - loss: 1.5097 - accuracy: 0.4461 - val_loss: 1.8278 - val_accuracy: 0.3866
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Removing a Fully Connected Layer

# %%
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(num_classes, name="outputs")
])
# we removed one of the fully connected layers

# %%
model.compile(optimizer="adam",
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_6 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 16)      448
#
#  max_pooling2d_18 (MaxPoolin  (None, 128, 128, 16)     0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 128, 128, 32)      4640
#
#  max_pooling2d_19 (MaxPoolin  (None, 64, 64, 32)       0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 64, 64, 64)        18496
#
#  max_pooling2d_20 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 65536)             0
#
#  outputs (Dense)             (None, 12)                786444
#
# ...
# Total params: 810,028
# Trainable params: 810,028
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 294/294 [==============================] - 261s 886ms/step - loss: 1.8129 - accuracy: 0.3979 - val_loss: 1.5560 - val_accuracy: 0.4689
# Epoch 2/10
# 294/294 [==============================] - 258s 878ms/step - loss: 1.3698 - accuracy: 0.5340 - val_loss: 1.4354 - val_accuracy: 0.5264
# Epoch 3/10
# 294/294 [==============================] - 257s 876ms/step - loss: 1.0608 - accuracy: 0.6385 - val_loss: 1.5174 - val_accuracy: 0.5175
# Epoch 4/10
# 294/294 [==============================] - 259s 880ms/step - loss: 0.7641 - accuracy: 0.7421 - val_loss: 1.7893 - val_accuracy: 0.5102
# Epoch 5/10
# 294/294 [==============================] - 258s 878ms/step - loss: 0.4827 - accuracy: 0.8386 - val_loss: 2.1316 - val_accuracy: 0.4996
# Epoch 6/10
# 294/294 [==============================] - 255s 868ms/step - loss: 0.2709 - accuracy: 0.9168 - val_loss: 2.5446 - val_accuracy: 0.4910
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Removing a Convolutional Layer

# %%
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(num_classes, name="outputs")
])

# %%
model.compile(optimizer="adam",
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 294/294 [==============================] - 213s 723ms/step - loss: 1.9366 - accuracy: 0.3766 - val_loss: 1.6288 - val_accuracy: 0.4403
# Epoch 2/10
# 294/294 [==============================] - 212s 720ms/step - loss: 1.4427 - accuracy: 0.5055 - val_loss: 1.5025 - val_accuracy: 0.4885
# Epoch 3/10
# 294/294 [==============================] - 212s 721ms/step - loss: 1.1359 - accuracy: 0.6194 - val_loss: 1.6144 - val_accuracy: 0.4714
# Epoch 4/10
# 294/294 [==============================] - 211s 718ms/step - loss: 0.8266 - accuracy: 0.7254 - val_loss: 1.6573 - val_accuracy: 0.4795
# Epoch 5/10
# 294/294 [==============================] - 212s 720ms/step - loss: 0.5368 - accuracy: 0.8290 - val_loss: 1.9987 - val_accuracy: 0.4557
# Epoch 6/10
# 294/294 [==============================] - 212s 721ms/step - loss: 0.3268 - accuracy: 0.9073 - val_loss: 2.2766 - val_accuracy: 0.4348
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Changing the Learning Rate

# %%
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 294/294 [==============================] - 284s 962ms/step - loss: 2.5375 - accuracy: 0.2921 - val_loss: 2.0414 - val_accuracy: 0.2937
# Epoch 2/10
# 294/294 [==============================] - 278s 946ms/step - loss: 2.0244 - accuracy: 0.3025 - val_loss: 1.9973 - val_accuracy: 0.2980
# Epoch 3/10
# 294/294 [==============================] - 278s 944ms/step - loss: 2.0004 - accuracy: 0.3036 - val_loss: 2.0041 - val_accuracy: 0.3142
# Epoch 4/10
# 294/294 [==============================] - 278s 945ms/step - loss: 1.9865 - accuracy: 0.3085 - val_loss: 2.0064 - val_accuracy: 0.2988
# Epoch 5/10
# 294/294 [==============================] - 279s 948ms/step - loss: 1.9831 - accuracy: 0.3057 - val_loss: 1.9834 - val_accuracy: 0.3031
# Epoch 6/10
# 294/294 [==============================] - 279s 947ms/step - loss: 1.9721 - accuracy: 0.3140 - val_loss: 1.9810 - val_accuracy: 0.3150
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.1),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 294/294 [==============================] - 336s 1s/step - loss: 2.1639 - accuracy: 0.3043 - val_loss: 2.1452 - val_accuracy: 0.2980
# Epoch 2/10
# 294/294 [==============================] - 331s 1s/step - loss: 2.1544 - accuracy: 0.3047 - val_loss: 2.1643 - val_accuracy: 0.2980
# Epoch 3/10
# 294/294 [==============================] - 331s 1s/step - loss: 2.1522 - accuracy: 0.3047 - val_loss: 2.1526 - val_accuracy: 0.2980
# Epoch 4/10
# 294/294 [==============================] - 330s 1s/step - loss: 2.1555 - accuracy: 0.3047 - val_loss: 2.1655 - val_accuracy: 0.2980
# Epoch 5/10
# 294/294 [==============================] - 332s 1s/step - loss: 2.1545 - accuracy: 0.3047 - val_loss: 2.1552 - val_accuracy: 0.2980
# Epoch 6/10
# 294/294 [==============================] - 331s 1s/step - loss: 2.1553 - accuracy: 0.3047 - val_loss: 2.1678 - val_accuracy: 0.2980
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Our Best Model

# %%
model = Sequential([
  data_augmentation2,
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer="adam",
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential (Sequential)     (None, 256, 256, 3)       0
#
#  rescaling (Rescaling)       (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 128)               8388736
#
#  dense_1 (Dense)             (None, 12)                1548
#
# ...
# Total params: 8,413,868
# Trainable params: 8,413,868
# Non-trainable params: 0
# ...

# %%
epochs = 25
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/25
# 295/295 [==============================] - 180s 546ms/step - loss: 2.2333 - accuracy: 0.2325 - val_loss: 2.0811 - val_accuracy: 0.2866
# Epoch 2/25
# 295/295 [==============================] - 174s 590ms/step - loss: 1.8166 - accuracy: 0.3693 - val_loss: 1.7063 - val_accuracy: 0.4047
# Epoch 3/25
# 295/295 [==============================] - 180s 611ms/step - loss: 1.6266 - accuracy: 0.4385 - val_loss: 1.5254 - val_accuracy: 0.4824
# Epoch 4/25
# 295/295 [==============================] - 176s 598ms/step - loss: 1.5069 - accuracy: 0.4797 - val_loss: 1.5644 - val_accuracy: 0.4709
# Epoch 5/25
# 295/295 [==============================] - 174s 589ms/step - loss: 1.4286 - accuracy: 0.5130 - val_loss: 1.4015 - val_accuracy: 0.5304
# Epoch 6/25
# 295/295 [==============================] - 168s 570ms/step - loss: 1.3206 - accuracy: 0.5480 - val_loss: 1.3505 - val_accuracy: 0.5185
# Epoch 7/25
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import os
import numpy as np
# def misclassified(directory):
# assign directory
directory = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Bridge'

i = 0
j = 0
k = 0
l = 0
m = 0
o = 0
p = 0
q = 0
r = 0
s = 0
t = 0
u = 0
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    img = tf.keras.utils.load_img(f, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])
#     print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 
#                                                                                            100 * np.max(score)))
    if class_names[np.argmax(score)] == 'Bridge':
        i = i+1
    elif class_names[np.argmax(score)] == 'Bicycle':
        j = j+1
    elif class_names[np.argmax(score)] == 'Bus':
        k = k+1
    elif class_names[np.argmax(score)] == 'Car':
        l = l+1
    elif class_names[np.argmax(score)] == 'Chimney':
        m = m+1
    elif class_names[np.argmax(score)] == 'Crosswalk':
        o = o+1
    elif class_names[np.argmax(score)] == 'Hydrant':
        p = p+1
    elif class_names[np.argmax(score)] == 'Motorcycle':
        q = q+1
    elif class_names[np.argmax(score)] == 'Palm':
        r = r+1
    elif class_names[np.argmax(score)] == 'Stair':
        s = s+1
    elif class_names[np.argmax(score)] == 'Traffic light':
        t = t+1
    else: u = u+1

num = len([entry for entry in os.listdir(directory) if os.path.isfile(os.path.join(directory, entry))])
# print("The classification rate for Bridge is:", i / num)
# print("Bridge was confused for Bicycle:", j / num)
# print("Bridge was confused for Bus:", k / num)
# print("Bridge was confused for Car:", l / num)
# print("Bridge was confused for Chimney:", m / num)
# print("Bridge was confused for Crosswalk:", o / num)
# print("Bridge was confused for Hydrant:", p / num)
# print("Bridge was confused for Motorcycle:", q / num)
# print("Bridge was confused for Palm:", r / num)
# print("Bridge was confused for Stair:", s / num)
# print("Bridge was confused for Traffic light:", t / num)

import matplotlib.pyplot as plt

y = np.array([i,j,k,l,m,o,p,q,r,s,t,u])
labels = ["Bridge", "Bicycle", "Bus", "Car", "Chimney", "Crosswalk", 
          "Hydrant", "Motorcycle", "Palm", "Stair", "Traffic Light", "Other"]

plt.pie(y)
plt.title("Bridge Classification")
plt.legend(labels=labels)
plt.show()

# %%
# Trying to actually be smart about this and create a function + for loop
# directory1 = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Bicycle'
# directory2 = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Bridge'
# directory3 = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Bus'
# directory4 = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Car'
# directory5 = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Chimney'
# directory6 = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Crosswalk'
# directory7 = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Hydrant'
# directory8 = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Motorcycle'
# directory9 = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Palm'
# directory10 = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Stair'
# directory11 = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Traffic light'

# directories = [directory1, directory2, directory3, directory4, directory5, directory6, directory7, directory8, 
#                directory9, directory10, directory11]

# for directory in directories:
#     map(misclassified, directory)

# %%
directory = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Bicycle'

i = 0
j = 0
k = 0
l = 0
m = 0
o = 0
p = 0
q = 0
r = 0
s = 0
t = 0
u = 0
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    img = tf.keras.utils.load_img(f, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])
#     print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 
#                                                                                            100 * np.max(score)))
    if class_names[np.argmax(score)] == 'Bridge':
        i = i+1
    elif class_names[np.argmax(score)] == 'Bicycle':
        j = j+1
    elif class_names[np.argmax(score)] == 'Bus':
        k = k+1
    elif class_names[np.argmax(score)] == 'Car':
        l = l+1
    elif class_names[np.argmax(score)] == 'Chimney':
        m = m+1
    elif class_names[np.argmax(score)] == 'Crosswalk':
        o = o+1
    elif class_names[np.argmax(score)] == 'Hydrant':
        p = p+1
    elif class_names[np.argmax(score)] == 'Motorcycle':
        q = q+1
    elif class_names[np.argmax(score)] == 'Palm':
        r = r+1
    elif class_names[np.argmax(score)] == 'Stair':
        s = s+1
    elif class_names[np.argmax(score)] == 'Traffic light':
        t = t+1
    else: u = u+1

y = np.array([i,j,k,l,m,o,p,q,r,s,t,u])
labels = ["Bridge", "Bicycle", "Bus", "Car", "Chimney", "Crosswalk", 
          "Hydrant", "Motorcycle", "Palm", "Stair", "Traffic Light", "Other"]

plt.pie(y)
plt.title("Bicycle Classification")
plt.legend(labels=labels)
plt.show()

# %%
directory = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Bus'

i = 0
j = 0
k = 0
l = 0
m = 0
o = 0
p = 0
q = 0
r = 0
s = 0
t = 0
u = 0
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    img = tf.keras.utils.load_img(f, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])
#     print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 
#                                                                                            100 * np.max(score)))
    if class_names[np.argmax(score)] == 'Bridge':
        i = i+1
    elif class_names[np.argmax(score)] == 'Bicycle':
        j = j+1
    elif class_names[np.argmax(score)] == 'Bus':
        k = k+1
    elif class_names[np.argmax(score)] == 'Car':
        l = l+1
    elif class_names[np.argmax(score)] == 'Chimney':
        m = m+1
    elif class_names[np.argmax(score)] == 'Crosswalk':
        o = o+1
    elif class_names[np.argmax(score)] == 'Hydrant':
        p = p+1
    elif class_names[np.argmax(score)] == 'Motorcycle':
        q = q+1
    elif class_names[np.argmax(score)] == 'Palm':
        r = r+1
    elif class_names[np.argmax(score)] == 'Stair':
        s = s+1
    elif class_names[np.argmax(score)] == 'Traffic light':
        t = t+1
    else: u = u+1

y = np.array([i,j,k,l,m,o,p,q,r,s,t,u])
labels = ["Bridge", "Bicycle", "Bus", "Car", "Chimney", "Crosswalk", 
          "Hydrant", "Motorcycle", "Palm", "Stair", "Traffic Light", "Other"]

plt.pie(y)
plt.title("Bus Classification")
plt.legend(labels=labels)
plt.show()

# %%
directory = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Car'

i = 0
j = 0
k = 0
l = 0
m = 0
o = 0
p = 0
q = 0
r = 0
s = 0
t = 0
u = 0
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    img = tf.keras.utils.load_img(f, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])
#     print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 
#                                                                                            100 * np.max(score)))
    if class_names[np.argmax(score)] == 'Bridge':
        i = i+1
    elif class_names[np.argmax(score)] == 'Bicycle':
        j = j+1
    elif class_names[np.argmax(score)] == 'Bus':
        k = k+1
    elif class_names[np.argmax(score)] == 'Car':
        l = l+1
    elif class_names[np.argmax(score)] == 'Chimney':
        m = m+1
    elif class_names[np.argmax(score)] == 'Crosswalk':
        o = o+1
    elif class_names[np.argmax(score)] == 'Hydrant':
        p = p+1
    elif class_names[np.argmax(score)] == 'Motorcycle':
        q = q+1
    elif class_names[np.argmax(score)] == 'Palm':
        r = r+1
    elif class_names[np.argmax(score)] == 'Stair':
        s = s+1
    elif class_names[np.argmax(score)] == 'Traffic light':
        t = t+1
    else: u = u+1

y = np.array([i,j,k,l,m,o,p,q,r,s,t,u])
labels = ["Bridge", "Bicycle", "Bus", "Car", "Chimney", "Crosswalk", 
          "Hydrant", "Motorcycle", "Palm", "Stair", "Traffic Light", "Other"]

plt.pie(y)
plt.title("Car Classification")
plt.legend(labels=labels)
plt.show()

# %%
directory = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Chimney'

i = 0
j = 0
k = 0
l = 0
m = 0
o = 0
p = 0
q = 0
r = 0
s = 0
t = 0
u = 0
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    img = tf.keras.utils.load_img(f, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])
#     print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 
#                                                                                            100 * np.max(score)))
    if class_names[np.argmax(score)] == 'Bridge':
        i = i+1
    elif class_names[np.argmax(score)] == 'Bicycle':
        j = j+1
    elif class_names[np.argmax(score)] == 'Bus':
        k = k+1
    elif class_names[np.argmax(score)] == 'Car':
        l = l+1
    elif class_names[np.argmax(score)] == 'Chimney':
        m = m+1
    elif class_names[np.argmax(score)] == 'Crosswalk':
        o = o+1
    elif class_names[np.argmax(score)] == 'Hydrant':
        p = p+1
    elif class_names[np.argmax(score)] == 'Motorcycle':
        q = q+1
    elif class_names[np.argmax(score)] == 'Palm':
        r = r+1
    elif class_names[np.argmax(score)] == 'Stair':
        s = s+1
    elif class_names[np.argmax(score)] == 'Traffic light':
        t = t+1
    else: u = u+1

y = np.array([i,j,k,l,m,o,p,q,r,s,t,u])
labels = ["Bridge", "Bicycle", "Bus", "Car", "Chimney", "Crosswalk", 
          "Hydrant", "Motorcycle", "Palm", "Stair", "Traffic Light", "Other"]

plt.pie(y)
plt.title("Chimney Classification")
plt.legend(labels=labels)
plt.show()

# %%
directory = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Crosswalk'

i = 0
j = 0
k = 0
l = 0
m = 0
o = 0
p = 0
q = 0
r = 0
s = 0
t = 0
u = 0
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    img = tf.keras.utils.load_img(f, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])
#     print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 
#                                                                                            100 * np.max(score)))
    if class_names[np.argmax(score)] == 'Bridge':
        i = i+1
    elif class_names[np.argmax(score)] == 'Bicycle':
        j = j+1
    elif class_names[np.argmax(score)] == 'Bus':
        k = k+1
    elif class_names[np.argmax(score)] == 'Car':
        l = l+1
    elif class_names[np.argmax(score)] == 'Chimney':
        m = m+1
    elif class_names[np.argmax(score)] == 'Crosswalk':
        o = o+1
    elif class_names[np.argmax(score)] == 'Hydrant':
        p = p+1
    elif class_names[np.argmax(score)] == 'Motorcycle':
        q = q+1
    elif class_names[np.argmax(score)] == 'Palm':
        r = r+1
    elif class_names[np.argmax(score)] == 'Stair':
        s = s+1
    elif class_names[np.argmax(score)] == 'Traffic light':
        t = t+1
    else: u = u+1

y = np.array([i,j,k,l,m,o,p,q,r,s,t,u])
labels = ["Bridge", "Bicycle", "Bus", "Car", "Chimney", "Crosswalk", 
          "Hydrant", "Motorcycle", "Palm", "Stair", "Traffic Light", "Other"]

plt.pie(y)
plt.title("Crosswalk Classification")
plt.legend(labels=labels)
plt.show()

# %%
directory = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Hydrant'

i = 0
j = 0
k = 0
l = 0
m = 0
o = 0
p = 0
q = 0
r = 0
s = 0
t = 0
u = 0
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    img = tf.keras.utils.load_img(f, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])
#     print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 
#                                                                                            100 * np.max(score)))
    if class_names[np.argmax(score)] == 'Bridge':
        i = i+1
    elif class_names[np.argmax(score)] == 'Bicycle':
        j = j+1
    elif class_names[np.argmax(score)] == 'Bus':
        k = k+1
    elif class_names[np.argmax(score)] == 'Car':
        l = l+1
    elif class_names[np.argmax(score)] == 'Chimney':
        m = m+1
    elif class_names[np.argmax(score)] == 'Crosswalk':
        o = o+1
    elif class_names[np.argmax(score)] == 'Hydrant':
        p = p+1
    elif class_names[np.argmax(score)] == 'Motorcycle':
        q = q+1
    elif class_names[np.argmax(score)] == 'Palm':
        r = r+1
    elif class_names[np.argmax(score)] == 'Stair':
        s = s+1
    elif class_names[np.argmax(score)] == 'Traffic light':
        t = t+1
    else: u = u+1

y = np.array([i,j,k,l,m,o,p,q,r,s,t,u])
labels = ["Bridge", "Bicycle", "Bus", "Car", "Chimney", "Crosswalk", 
          "Hydrant", "Motorcycle", "Palm", "Stair", "Traffic Light", "Other"]

plt.pie(y)
plt.title("Hydrant Classification")
plt.legend(labels=labels)
plt.show()

# %%
directory = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Motorcycle'

i = 0
j = 0
k = 0
l = 0
m = 0
o = 0
p = 0
q = 0
r = 0
s = 0
t = 0
u = 0
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    img = tf.keras.utils.load_img(f, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])
#     print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 
#                                                                                            100 * np.max(score)))
    if class_names[np.argmax(score)] == 'Bridge':
        i = i+1
    elif class_names[np.argmax(score)] == 'Bicycle':
        j = j+1
    elif class_names[np.argmax(score)] == 'Bus':
        k = k+1
    elif class_names[np.argmax(score)] == 'Car':
        l = l+1
    elif class_names[np.argmax(score)] == 'Chimney':
        m = m+1
    elif class_names[np.argmax(score)] == 'Crosswalk':
        o = o+1
    elif class_names[np.argmax(score)] == 'Hydrant':
        p = p+1
    elif class_names[np.argmax(score)] == 'Motorcycle':
        q = q+1
    elif class_names[np.argmax(score)] == 'Palm':
        r = r+1
    elif class_names[np.argmax(score)] == 'Stair':
        s = s+1
    elif class_names[np.argmax(score)] == 'Traffic light':
        t = t+1
    else: u = u+1

y = np.array([i,j,k,l,m,o,p,q,r,s,t,u])
labels = ["Bridge", "Bicycle", "Bus", "Car", "Chimney", "Crosswalk", 
          "Hydrant", "Motorcycle", "Palm", "Stair", "Traffic Light", "Other"]

plt.pie(y)
plt.title("Motorcycle Classification")
plt.legend(labels=labels)
plt.show()

# %%
directory = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Palm'

i = 0
j = 0
k = 0
l = 0
m = 0
o = 0
p = 0
q = 0
r = 0
s = 0
t = 0
u = 0
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    img = tf.keras.utils.load_img(f, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])
#     print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 
#                                                                                            100 * np.max(score)))
    if class_names[np.argmax(score)] == 'Bridge':
        i = i+1
    elif class_names[np.argmax(score)] == 'Bicycle':
        j = j+1
    elif class_names[np.argmax(score)] == 'Bus':
        k = k+1
    elif class_names[np.argmax(score)] == 'Car':
        l = l+1
    elif class_names[np.argmax(score)] == 'Chimney':
        m = m+1
    elif class_names[np.argmax(score)] == 'Crosswalk':
        o = o+1
    elif class_names[np.argmax(score)] == 'Hydrant':
        p = p+1
    elif class_names[np.argmax(score)] == 'Motorcycle':
        q = q+1
    elif class_names[np.argmax(score)] == 'Palm':
        r = r+1
    elif class_names[np.argmax(score)] == 'Stair':
        s = s+1
    elif class_names[np.argmax(score)] == 'Traffic light':
        t = t+1
    else: u = u+1

y = np.array([i,j,k,l,m,o,p,q,r,s,t,u])
labels = ["Bridge", "Bicycle", "Bus", "Car", "Chimney", "Crosswalk", 
          "Hydrant", "Motorcycle", "Palm", "Stair", "Traffic Light", "Other"]

plt.pie(y)
plt.title("Palm Classification")
plt.legend(labels=labels)
plt.show()

# %%
directory = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Stair'

i = 0
j = 0
k = 0
l = 0
m = 0
o = 0
p = 0
q = 0
r = 0
s = 0
t = 0
u = 0
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    img = tf.keras.utils.load_img(f, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])
#     print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 
#                                                                                            100 * np.max(score)))
    if class_names[np.argmax(score)] == 'Bridge':
        i = i+1
    elif class_names[np.argmax(score)] == 'Bicycle':
        j = j+1
    elif class_names[np.argmax(score)] == 'Bus':
        k = k+1
    elif class_names[np.argmax(score)] == 'Car':
        l = l+1
    elif class_names[np.argmax(score)] == 'Chimney':
        m = m+1
    elif class_names[np.argmax(score)] == 'Crosswalk':
        o = o+1
    elif class_names[np.argmax(score)] == 'Hydrant':
        p = p+1
    elif class_names[np.argmax(score)] == 'Motorcycle':
        q = q+1
    elif class_names[np.argmax(score)] == 'Palm':
        r = r+1
    elif class_names[np.argmax(score)] == 'Stair':
        s = s+1
    elif class_names[np.argmax(score)] == 'Traffic light':
        t = t+1
    else: u = u+1

y = np.array([i,j,k,l,m,o,p,q,r,s,t,u])
labels = ["Bridge", "Bicycle", "Bus", "Car", "Chimney", "Crosswalk", 
          "Hydrant", "Motorcycle", "Palm", "Stair", "Traffic Light", "Other"]

plt.pie(y)
plt.title("Stair Classification")
plt.legend(labels=labels)
plt.show()

# %%
directory = r'C:\Users\jmand\OneDrive\Desktop\Google_Recaptcha_V2_Images_Dataset - Copy\images\Traffic light'

i = 0
j = 0
k = 0
l = 0
m = 0
o = 0
p = 0
q = 0
r = 0
s = 0
t = 0
u = 0
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    img = tf.keras.utils.load_img(f, target_size=(img_height, img_width))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])
#     print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 
#                                                                                            100 * np.max(score)))
    if class_names[np.argmax(score)] == 'Bridge':
        i = i+1
    elif class_names[np.argmax(score)] == 'Bicycle':
        j = j+1
    elif class_names[np.argmax(score)] == 'Bus':
        k = k+1
    elif class_names[np.argmax(score)] == 'Car':
        l = l+1
    elif class_names[np.argmax(score)] == 'Chimney':
        m = m+1
    elif class_names[np.argmax(score)] == 'Crosswalk':
        o = o+1
    elif class_names[np.argmax(score)] == 'Hydrant':
        p = p+1
    elif class_names[np.argmax(score)] == 'Motorcycle':
        q = q+1
    elif class_names[np.argmax(score)] == 'Palm':
        r = r+1
    elif class_names[np.argmax(score)] == 'Stair':
        s = s+1
    elif class_names[np.argmax(score)] == 'Traffic light':
        t = t+1
    else: u = u+1

y = np.array([i,j,k,l,m,o,p,q,r,s,t,u])
labels = ["Bridge", "Bicycle", "Bus", "Car", "Chimney", "Crosswalk", 
          "Hydrant", "Motorcycle", "Palm", "Stair", "Traffic Light", "Other"]

plt.pie(y)
plt.title("Traffic light")
plt.legend(labels=labels)
plt.show()

# %% [markdown]
# # Segmenting the Recaptcha Test into a 9 image classification problem

# %%
from PIL import Image
 
im = Image.open(r"recaptchademotest.png")

# Setting the points for cropped image
left = 10
top = 160
right = 165
bottom = 315
 
# Cropped image of above dimension
# (It will not change original image)
im1 = im.crop((left, top, right, bottom))
im1 = im1.save("im1.png")

left2 = 170
top2 = 160
right2 = 330
bottom2 = 315
im2 = im.crop((left2, top2, right2, bottom2))
im2 = im2.save("im2.png")

left3 = 335
top3 = 160
right3 = 490
bottom3 = 315
im3 = im.crop((left3, top3, right3, bottom3))
im3 = im3.save("im3.png")

left4 = 10
top4 = 320
right4 = 165
bottom4 = 480
im4 = im.crop((left4, top4, right4, bottom4))
im4 = im4.save("im4.png")

left5 = 170
top5 = 320
right5 = 330
bottom5 = 480
im5 = im.crop((left5, top5, right5, bottom5))
im5 = im5.save("im5.png")

left6 = 335
top6 = 320
right6 = 490
bottom6 = 480
im6 = im.crop((left6, top6, right6, bottom6))
im6 = im6.save("im6.png")

left7 = 10
top7 = 485
right7 = 165
bottom7 = 640
im7 = im.crop((left7, top7, right7, bottom7))
im7 = im7.save("im7.png")

left8 = 170
top8 = 485
right8 = 330
bottom8 = 640
im8 = im.crop((left8, top8, right8, bottom8))
im8 = im8.save("im8.png")

left9 = 335
top9 = 485
right9 = 490
bottom9 = 640 
im9 = im.crop((left9, top9, right9, bottom9))
im9 = im9.save("im9.png")

# %% [markdown]
# # Running these 9 images through the CNN

# %%
import numpy as np
# sunflower_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg"
# recaptcha_demolist = [im,im2,im3,im4,im5,im6,im7,im8,im9]
# sunflower_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)

# need to save images to pc and go from there

img = tf.keras.utils.load_img("im1.png", target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print("The first image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score)))

img = tf.keras.utils.load_img("im2.png", target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print("The second image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score)))

img = tf.keras.utils.load_img("im3.png", target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print("The third image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 
                                                                                           100 * np.max(score)))

img = tf.keras.utils.load_img("im4.png", target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print("The fourth image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score)))

img = tf.keras.utils.load_img("im5.png", target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print("The fifth image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score)))

img = tf.keras.utils.load_img("im6.png", target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print("The sixth image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score)))

img = tf.keras.utils.load_img("im7.png", target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print("The seventh image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score)))

img = tf.keras.utils.load_img("im8.png", target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print("The eigth image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score)))

img = tf.keras.utils.load_img("im9.png", target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print("The ninth image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score)))

# default is .001
# Out:
# 1/1 [==============================] - 1s 879ms/step
# The first image most likely belongs to Crosswalk with a 47.64 percent confidence.
# 1/1 [==============================] - 0s 47ms/step
# The second image most likely belongs to Hydrant with a 99.99 percent confidence.
# 1/1 [==============================] - 0s 55ms/step
# The third image most likely belongs to Palm with a 42.99 percent confidence.
# 1/1 [==============================] - 0s 65ms/step
# The fourth image most likely belongs to Car with a 42.04 percent confidence.
# 1/1 [==============================] - 0s 51ms/step
# The fifth image most likely belongs to Hydrant with a 99.83 percent confidence.
# 1/1 [==============================] - 0s 50ms/step
# The sixth image most likely belongs to Bus with a 85.78 percent confidence.
# 1/1 [==============================] - 0s 52ms/step
# The seventh image most likely belongs to Hydrant with a 100.00 percent confidence.
# ...

# %% [markdown]
# # Not included in project: What if we modify these 9 images by axis rotation, flipped axes, or gray colorscale?

# %%
# from skimage import data
# from skimage.color import rgb2gray
# from skimage.color import rgb2hsv
# import cv2

# %%
# originalImage = 'recaptchademotest.png'
# flipVertical = cv2.flip(originalImage, 0)
# flipHorizontal = cv2.flip(originalImage, 1)
# flipBoth = cv2.flip(originalImage, -1)

# cv2.imshow('Original image', originalImage)
# cv2.imshow('Flipped vertical image', flipVertical)
# cv2.imshow('Flipped horizontal image', flipHorizontal)
# cv2.imshow('Flipped both image', flipBoth)
